# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank1325/Customer-Analytics/blob/main/FR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
import numpy as np

# %%
event_df = pd.read_excel('/content/FrontRow_Data Analyst Assignment.xlsx',sheet_name='Dump - User IDs')

# %%
event_df.head()
# Out:
#    2020-01-01  2020-01-02  2020-01-03  ...  2020-03-29  2020-03-30  2020-03-31
# 0      2154.0      3539.0         2.0  ...      1524.0         3.0         3.0
# 1      6286.0      4522.0      4508.0  ...      1525.0      1524.0       817.0
# 2         NaN      4511.0      3539.0  ...       364.0       817.0      6247.0
# 3         NaN      4523.0      4509.0  ...       541.0      6247.0      6274.0
# 4         NaN      4503.0      4510.0  ...       437.0      6274.0         6.0
#
# [5 rows x 91 columns]

# %%
event_df.drop_duplicates()
# Out:
#      2020-01-01  2020-01-02  2020-01-03  ...  2020-03-29  2020-03-30  2020-03-31
# 0        2154.0      3539.0         2.0  ...      1524.0         3.0         3.0
# 1        6286.0      4522.0      4508.0  ...      1525.0      1524.0       817.0
# 2           NaN      4511.0      3539.0  ...       364.0       817.0      6247.0
# 3           NaN      4523.0      4509.0  ...       541.0      6247.0      6274.0
# 4           NaN      4503.0      4510.0  ...       437.0      6274.0         6.0
# ..          ...         ...         ...  ...         ...         ...         ...
# 403         NaN         NaN         NaN  ...         NaN         NaN      1643.0
# 404         NaN         NaN         NaN  ...         NaN         NaN      1889.0
# 405         NaN         NaN         NaN  ...         NaN         NaN      1782.0
# 406         NaN         NaN         NaN  ...         NaN         NaN      1890.0
# 407         NaN         NaN         NaN  ...         NaN         NaN         NaN
#
# ...

# %%
d=event_df.to_dict('list')
print (d)
# Out:
# {Timestamp('2020-01-01 00:00:00'): [2154.0, 6286.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, n
# ...

# %%
l=list(d.values())
print(l)
# Out:
# [[2154.0, 6286.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 
# ...

# %%
import itertools
flat=itertools.chain.from_iterable(l)
List= list(flat)
print(List)
# Out:
# [2154.0, 6286.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, n
# ...

# %%
L = [x for x in List if str(x) != 'nan']
print(L)
# Out:
# [2154.0, 6286.0, 3539.0, 4522.0, 4511.0, 4523.0, 4503.0, 4504.0, 4524.0, 3450.0, 4525.0, 4073.0, 4526.0, 4527.0, 2975.0, 4515.0, 2697.0, 4528.0, 4529.0, 4530.0, 153.0, 4248.0, 4520.0, 4531.0, 2552.0, 4532.0, 4533.0, 4385.0, 3977.0, 4534.0, 2759.0, 2.0, 4508.0, 3539.0, 4509.0, 4510.0, 4431.0, 3998.0, 4511.0, 309.0, 2165.0, 4503.0, 4512.0, 3054.0, 3450.0, 3719.0, 1165.0, 4073.0, 4484.0, 4513.0, 6287.0, 4514.0, 2975.0, 4515.0, 3424.0, 4516.0, 3966.0, 4517.0, 4518.0, 2380.0, 153.0, 4505.0, 4519.0, 3461.0, 4248.0, 3989.0, 4520.0, 2552.0, 4506.0, 4521.0, 4461.0, 3531.0, 4507.0, 2.0, 223.0, 4430.0, 4431.0, 2165.0, 4503.0, 4504.0, 3054.0, 3450.0, 251.0, 4223.0, 6287.0, 2975.0, 3573.0, 3424.0, 2697.0, 2380.0, 153.0, 4505.0, 3461.0, 347.0, 3989.0, 4506.0, 189.0, 4461.0, 1774.0, 4507.0, 4466.0, 4467.0, 4468.0, 4469.0, 4470.0, 223.0, 4471.0, 4472.0, 4473.0, 300.0, 4474.0, 4430.0, 448.0, 4475.0, 4476.0, 4477.0, 237.0, 4478.0, 4352.0, 385.0, 4479.0, 4480.0, 4394.0, 3054.0, 4481.0, 3616.0, 4397.0, 
# ...

# %%
res = [] 
for i in L: 
    if i not in res: 
        res.append(i)

# %%
print (str(res))
# Out:
# [2154.0, 6286.0, 3539.0, 4522.0, 4511.0, 4523.0, 4503.0, 4504.0, 4524.0, 3450.0, 4525.0, 4073.0, 4526.0, 4527.0, 2975.0, 4515.0, 2697.0, 4528.0, 4529.0, 4530.0, 153.0, 4248.0, 4520.0, 4531.0, 2552.0, 4532.0, 4533.0, 4385.0, 3977.0, 4534.0, 2759.0, 2.0, 4508.0, 4509.0, 4510.0, 4431.0, 3998.0, 309.0, 2165.0, 4512.0, 3054.0, 3719.0, 1165.0, 4484.0, 4513.0, 6287.0, 4514.0, 3424.0, 4516.0, 3966.0, 4517.0, 4518.0, 2380.0, 4505.0, 4519.0, 3461.0, 3989.0, 4506.0, 4521.0, 4461.0, 3531.0, 4507.0, 223.0, 4430.0, 251.0, 4223.0, 3573.0, 347.0, 189.0, 1774.0, 4466.0, 4467.0, 4468.0, 4469.0, 4470.0, 4471.0, 4472.0, 4473.0, 300.0, 4474.0, 448.0, 4475.0, 4476.0, 4477.0, 237.0, 4478.0, 4352.0, 385.0, 4479.0, 4480.0, 4394.0, 4481.0, 3616.0, 4397.0, 4353.0, 4482.0, 4033.0, 4029.0, 4401.0, 1923.0, 3917.0, 4355.0, 4483.0, 2430.0, 3416.0, 3921.0, 3924.0, 4405.0, 110.0, 4359.0, 4485.0, 4444.0, 4486.0, 4236.0, 4487.0, 4035.0, 4488.0, 4489.0, 4446.0, 4490.0, 4491.0, 4492.0, 4450.0, 4493.0, 3971.0, 4453.0, 449
# ...

# %%
Unique_cust=len(res)
Unique_cust
# Out:
# 4594

# %% [markdown]
# # DAU Variation

# %%
df= event_df.count(0).to_frame()

# %%
df.head()
# Out:
#              0
# 2020-01-01   2
# 2020-01-02  29
# 2020-01-03  42
# 2020-01-04  27
# 2020-01-05  91

# %%
df.plot(legend=False)
plt.title('DAU Variation')
plt.xlabel('Day')
plt.ylabel('DAU')
# Out:
# Text(0, 0.5, 'DAU')

# %%
df.shape
# Out:
# (91, 1)

# %%
df.dtypes
# Out:
# 0    int64
# dtype: object

# %%
df.reset_index(level=0, inplace=True)

# %%
df
# Out:
#         index    0
# 0  2020-01-01    2
# 1  2020-01-02   29
# 2  2020-01-03   42
# 3  2020-01-04   27
# 4  2020-01-05   91
# ..        ...  ...
# 86 2020-03-27  302
# 87 2020-03-28  323
# 88 2020-03-29  327
# 89 2020-03-30  348
# 90 2020-03-31  407
#
# [91 rows x 2 columns]

# %%
new_df = df.rename(columns = {"Index": "Date"})

# %% [markdown]
# # Jan MAU

# %%
jan_df=event_df.iloc[:, 0:31]

# %%
jan_df.head()
# Out:
#    2020-01-01  2020-01-02  2020-01-03  ...  2020-01-29  2020-01-30  2020-01-31
# 0      2154.0      3539.0         2.0  ...         8.0      3833.0      3833.0
# 1      6286.0      4522.0      4508.0  ...      3874.0      3760.0      3834.0
# 2         NaN      4511.0      3539.0  ...      3787.0      3303.0      3760.0
# 3         NaN      4523.0      4509.0  ...      3303.0      3386.0       292.0
# 4         NaN      4503.0      4510.0  ...        26.0      2954.0      3384.0
#
# [5 rows x 31 columns]

# %%
d1=jan_df.to_dict('list')

# %%
l1=list(d1.values())

# %%
import itertools
flat1=itertools.chain.from_iterable(l1)
List1= list(flat1)

# %%
L1 = [x for x in List1 if str(x) != 'nan']

# %%
res1 = [] 
for i in L1: 
    if i not in res1: 
        res1.append(i)

# %%
print(len(res1))
# Out:
# 921

# %%
df1= jan_df.count(0).to_frame()

# %%
df1.tail()
# Out:
#              0
# 2020-01-27  47
# 2020-01-28  91
# 2020-01-29  85
# 2020-01-30  60
# 2020-01-31  97

# %%
df1.columns =['DAU']

# %%
df1.head()
# Out:
#             DAU
# 2020-01-01    2
# 2020-01-02   29
# 2020-01-03   42
# 2020-01-04   27
# 2020-01-05   91

# %%
df1['Ratio']=df1['DAU']/921*100

# %%
df1.head()
# Out:
#             DAU     Ratio
# 2020-01-01    2  0.217155
# 2020-01-02   29  3.148751
# 2020-01-03   42  4.560261
# 2020-01-04   27  2.931596
# 2020-01-05   91  9.880565

# %%
jan= df1.drop(columns=['DAU'])

# %%
jan.plot()
plt.title('Jan_Retention')
plt.xlabel('Day')
plt.ylabel('DAU/MAU*100')
# Out:
# Text(0, 0.5, 'DAU/MAU*100')

# %%
Stats_jan=df1['Ratio'].describe()
Stats_jan
# Out:
# count    31.000000
# mean      7.407797
# std       4.653892
# min       0.217155
# 25%       3.854506
# 50%       5.863192
# 75%       9.880565
# max      17.806732
# Name: Ratio, dtype: float64

# %%
df1.plot()

# %% [markdown]
# # Feb MAU

# %%
feb_df=event_df.iloc[:, 31:60]

# %%
feb_df.head()
# Out:
#    2020-02-01  2020-02-02  2020-02-03  ...  2020-02-27  2020-02-28  2020-02-29
# 0      3811.0         8.0      2561.0  ...      2682.0      2760.0      2760.0
# 1      3812.0      3785.0         8.0  ...      2760.0      2804.0         7.0
# 2      3760.0        18.0      3760.0  ...      2804.0       365.0      2649.0
# 3        18.0      2291.0       292.0  ...       434.0         8.0      2761.0
# 4      2291.0      3563.0        18.0  ...      2853.0      2354.0       293.0
#
# [5 rows x 29 columns]

# %%
d2=feb_df.to_dict('list')

# %%
l2=list(d2.values())

# %%
import itertools
flat2=itertools.chain.from_iterable(l2)
List2= list(flat2)

# %%
L2 = [x for x in List2 if str(x) != 'nan']

# %%
res2 = [] 
for i in L2: 
    if i not in res2: 
        res2.append(i)

# %%
print(len(res2))
# Out:
# 1537

# %%
df2= feb_df.count(0).to_frame()

# %%
df2.columns =['DAU']

# %%
df2['Ratio']=df2['DAU']/1537*100
df2.head()
# Out:
#             DAU     Ratio
# 2020-02-01   88  5.725439
# 2020-02-02  110  7.156799
# 2020-02-03  107  6.961614
# 2020-02-04  122  7.937541
# 2020-02-05  114  7.417046

# %%
feb= df2.drop(columns=['DAU'])
feb.head()
# Out:
#                Ratio
# 2020-02-01  5.725439
# 2020-02-02  7.156799
# 2020-02-03  6.961614
# 2020-02-04  7.937541
# 2020-02-05  7.417046

# %%
feb.plot()
plt.title('Feb_Retention')
plt.xlabel('Day')
plt.ylabel('DAU/MAU*100')
# Out:
# Text(0, 0.5, 'DAU/MAU*100')

# %%
df2.plot()

# %%
Stats_feb=df2['Ratio'].describe()
Stats_feb
# Out:
# count    29.000000
# mean      9.694209
# std       2.801977
# min       5.725439
# 25%       7.417046
# 50%       9.368900
# 75%      12.231620
# max      16.265452
# Name: Ratio, dtype: float64

# %% [markdown]
# # March

# %%
mar_df=event_df.iloc[:, 60:91]

# %%
mar_df.head()
# Out:
#    2020-03-01  2020-03-02  2020-03-03  ...  2020-03-29  2020-03-30  2020-03-31
# 0      2710.0      2682.0         3.0  ...      1524.0         3.0         3.0
# 1      2649.0         7.0         7.0  ...      1525.0      1524.0       817.0
# 2      2711.0      2228.0         8.0  ...       364.0       817.0      6247.0
# 3        17.0         8.0      2649.0  ...       541.0      6247.0      6274.0
# 4       294.0      2649.0        17.0  ...       437.0      6274.0         6.0
#
# [5 rows x 31 columns]

# %%
d3=mar_df.to_dict('list')

# %%
l3=list(d3.values())

# %%
import itertools
flat3=itertools.chain.from_iterable(l3)
List3= list(flat3)

# %%
L3 = [x for x in List3 if str(x) != 'nan']

# %%
res3 = [] 
for i in L3: 
    if i not in res3: 
        res3.append(i)

# %%
print(len(res3))
# Out:
# 2813

# %%
print(#Unique Customers=len(res1)+len(res2)+len(res3))
# Out:
# 5271

# %%
df3= mar_df.count(0).to_frame()

# %%
df3.columns =['DAU']

# %%
df3['Ratio']=df3['DAU']/2813*100
df3.head()
# Out:
#             DAU     Ratio
# 2020-03-01  168  5.972272
# 2020-03-02  141  5.012442
# 2020-03-03  158  5.616779
# 2020-03-04  108  3.839317
# 2020-03-05  126  4.479204

# %%
df3.plot()

# %%
df3.plot(y='Ratio')
plt.title('Mar_Retention')
plt.xlabel('Day')
plt.ylabel('DAU/MAU*100')
# Out:
# Text(0, 0.5, 'DAU/MAU*100')

# %%
data_df3 = df3.rename(columns = {"index": "Day"})

data_df3.head()
# Out:
#             DAU     Ratio
# 2020-03-01  168  5.972272
# 2020-03-02  141  5.012442
# 2020-03-03  158  5.616779
# 2020-03-04  108  3.839317
# 2020-03-05  126  4.479204

# %%
Stats_mar=df3['Ratio'].describe()
Stats_mar
# Out:
# count    31.000000
# mean      8.131601
# std       2.892741
# min       3.839317
# 25%       5.918948
# 50%       7.571987
# 75%      11.109136
# max      14.468539
# Name: Ratio, dtype: float64

# %%
frames = [df1, df2, df3]

# %%
result = pd.concat(frames)

# %%
result.head()
# Out:
#             DAU     Ratio
# 2020-01-01    2  0.217155
# 2020-01-02   29  3.148751
# 2020-01-03   42  4.560261
# 2020-01-04   27  2.931596
# 2020-01-05   91  9.880565

# %%
result.tail()
# Out:
#             DAU      Ratio
# 2020-03-27  302  10.735869
# 2020-03-28  323  11.482403
# 2020-03-29  327  11.624600
# 2020-03-30  348  12.371134
# 2020-03-31  407  14.468539

# %%
result.shape
# Out:
# (91, 2)

# %%
DAU_sum = result['DAU'].sum()
DAU_sum
# Out:
# 13527

# %%
Recurring_cust=DAU_sum-Unique_cust
Recurring_cust
# Out:
# 8933

# %%
Percent_Old_User=Recurring_cust/DAU_sum*100
Percent_Old_User
# Out:
# 66.03829378280476

# %%
result.plot(y='Ratio')
plt.title('Retention')
plt.xlabel('Day')
plt.ylabel('DAU/MAU*100')
# Out:
# Text(0, 0.5, 'DAU/MAU*100')

# %%
result.reset_index(level=0, inplace=True)
result.head()
# Out:
#        index  DAU     Ratio
# 0 2020-01-01    2  0.217155
# 1 2020-01-02   29  3.148751
# 2 2020-01-03   42  4.560261
# 3 2020-01-04   27  2.931596
# 4 2020-01-05   91  9.880565

# %%
result.shape
# Out:
# (91, 3)

# %%
result.rename(index={0:'Date'}, inplace=True)
result.head()
# Out:
#           index  DAU     Ratio
# Date 2020-01-01    2  0.217155
# 1    2020-01-02   29  3.148751
# 2    2020-01-03   42  4.560261
# 3    2020-01-04   27  2.931596
# 4    2020-01-05   91  9.880565

# %%
new_data = result.rename(columns = {"index": "Day"})

new_data.head()
# Out:
#             Day  DAU     Ratio
# Date 2020-01-01    2  0.217155
# 1    2020-01-02   29  3.148751
# 2    2020-01-03   42  4.560261
# 3    2020-01-04   27  2.931596
# 4    2020-01-05   91  9.880565

# %%
new_data["Day"]= pd.to_datetime(new_data["Day"])
new_data.head()
# Out:
#             Day  DAU     Ratio
# Date 2020-01-01    2  0.217155
# 1    2020-01-02   29  3.148751
# 2    2020-01-03   42  4.560261
# 3    2020-01-04   27  2.931596
# 4    2020-01-05   91  9.880565

# %%
new_data.shape
# Out:
# (91, 3)

# %%
new_data.dtypes
# Out:
# Day      datetime64[ns]
# DAU               int64
# Ratio           float64
# dtype: object

# %%
for col in new_data.columns: 
    print(col)
# Out:
# Day
# DAU
# Ratio

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as datetime

# %%
Mean_Ratio=new_data['Ratio'].mean()
Mean_Ratio
# Out:
# 8.383004390887056

# %%
Stats=new_data['Ratio'].describe()
Stats
# Out:
# count    91.000000
# mean      8.383004
# std       3.654418
# min       0.217155
# 25%       5.794316
# 50%       7.677293
# 75%      11.109136
# max      17.806732
# Name: Ratio, dtype: float64
